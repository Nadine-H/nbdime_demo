# %%
def func(x, y, z):
    return (x + y) * z

# %%
print(func(1,2, 3))
# Out:
# 6

# %%
print(func(1,1,1))
# Out:
# 3

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 5 + np.sin(5 * np.pi * t)

plt.plot(t, s)


plt.show()
